# %%
n = int(input()) #데이터의 개수 입력
data = list(map(int,input().split())) # 각 데이터를 공백으로 구분하여 입력
data.sort(reverse = True)
print(data)
n,m,k = map(int, input().split())
print(n,m,k)
# import sys
# data = sys.stdin.readline().rstrip() # colab이나 jupyter환경에서는 작동 x
# print(data)
a = 1
b = 2
print(a,b) # print()를 사용 시 마다 줄이 변경
print(a)
print(b)
answer = 7
# print('정답은' + answer '입니다.') #문자열은 문자열끼리만 더하기 연산이 가능(오류 발생)
print('정답은'+str(answer)+'입니다') # 변수를 문자열로 변경
print('정답은',answer,'입니다.') # 각 변수를 콤마로 구분하여 출력
# Out:
# 5
# 65 90 75 34 99
# [99, 90, 75, 65, 34]
# 3 5 7
# 3 5 7
# 1 2
# 1
# 2
# 정답은7입니다
# 정답은 7 입니다.
