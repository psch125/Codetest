# %%
### < 조건문 >
x = 15
if x>= 10 :
    print(x)

score = 85
if score >= 90 :
    print("학점 : A") # 성적이 90점 이상일 때 : A
elif score >= 80 :
    print('학점 : B') # 성적이 90점 미만, 80점 이상일 때 : B
elif score >=70 :
    print('학점 : C') # 성적이 80점 미만, 70점 이상일 때 : C
else :
    print('학점 : F') # 성적이 70점 미만일 때 : F

score = 85
if score >= 70 :
    print('성적이 70점 이상입니다.')
    if score >= 90 :
        print('우수한 성적입니다.')
else : 
    print('성적이 70점 미만입니다.')
    print('조금 더 분발하세요')
print('프로그램을 종료합니다.')

#비교 연산자
# X == Y : X와 Y가 서로 같을 때 참(True)이다.
# X != Y : X와 Y가 서로 다를 때 참(True)이다.
# X > Y : X가 Y보다 클 때 참(True)이다.
# X < Y : X가 Y보다 작을 때 참(True)이다.
# X >= Y : X가 Y보다 크거나 같을 때 참(True)이다.
# X <= Y : X가 Y보다 작거나 같을 때 참(True)이다.

#논리 연산자
# X and Y : X와 Y가 모두 참(True)일 때 참(True)이다.
# X or Y : X와 Y중에 하나만 참(True)이어도 참(True)이다.
# not X : X가 거짓(False)일 때 참(True)이다.

#파이썬의 기타 연산자
# X in 리스트 : 리스트 안에 X가 들어가 있을 떄 참(True)이다.
# X not in 문자열 : 문자열 안에 X가 들어가 있지 않을 때 참(True)이다.

#pass 사용법
score = 85
if score >= 80:
    pass # 나중에 작성할 소스 코드
else :
    print('성적이 80점 미만입니다.')
print('프로그램을 종료합니다.')
# 줄 바꿈 하지 않기
score = 85 
if score >= 80 : result = 'Success'
else : result = 'Fali'
#조건부 표현식
score = 85
result = 'Success' if score >= 80 else 'Fail'
print(result)
# Out:
# 15
# 학점 : B
# 성적이 70점 이상입니다.
# 프로그램을 종료합니다.
# 프로그램을 종료합니다.
# Success
