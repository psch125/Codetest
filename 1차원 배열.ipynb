# %%
#10818
A = int(input())
num_list =  list(map(int,input().split()))
print(min(num_list),max(num_list))

#2562 -3
num = []
for i in range(9) :
    A = int(input())
    num.append(A)        
max_num = max(num)
check = 0
for i in A :
    check= check+1
    if i == max_num :
        print(max_num)
        print(check)
        break
        
#2577 -3
A =int(input())
B =int(input())
C =int(input())

num = A*B*C
str_num = str(num)
for i in range(0,10) :
    globals()['check_'+str(i)] = 0
for i in str_num :
    if i == str(0) :
        check_0 = check_0+1
    elif i == str(1) :
        check_1 = check_1+1
    elif i == str(2) :
        check_2 = check_2+1
    elif i == str(3) :
        check_3 = check_3+1
    elif i == str(4) :
        check_4 = check_4+1
    elif i == str(5) :
        check_5 = check_5+1
    elif i == str(6) :
        check_6 = check_6+1
    elif i == str(7) :
        check_7 = check_7+1
    elif i == str(8) :
        check_8 = check_8+1
    else :
        check_9 = check_9+1
for i in range(0,10) :
    print(globals()['check_'+str(i)])
    
#3052 -3
check = []
for i in range(10) :
    num = int(input())  
    check.append(i%42)
check = set(check)
print(len(check))

#1546 -1
len = int(input())
exam_list = list(map(int,input().split()))
new_exam = []
check = 0
for i in exam_list :
  max_exam = max(exam_list)
  new_exam.append(i/max_exam*100)
  check += 1

Avg = 0
for i in new_exam :
  Avg = Avg + i
Avg = Avg / check
print(Avg)

#8958
length = int(input())

for i in range(length) :
  question = input()
  checker = 0
  score = 0
  for i in question :
    if i == 'O' :
      checker = checker+1
    if i == 'X' :
      checker = 0
    score = score + checker
  print(score)

# %%
C = int(input())
for i in range(C):
    check = 0
    list_num = list(map(int,input().split()))
    Avg = sum(list_num[1:]) / list_num[0]
    for j in list_num[1:] :
        if j > Avg :
            check = check+1
    check = (check / (len(list_num) -1)) * 100
    check = round(check,3)
    print(format((check),".3f")+'%')
# Out:
# 5
# 5 50 50 70 80 100
# 40.000%

# %%
3/4
# Out:
# 0.75

# %%
list_num = list(map(int,input().split()))
Avg = sum(list_num[1:]) / list_num[0]
# Out:
# 1 2 3 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-65df3f41e7f2> in <module>
#       2 list_num = list(map(int,input().split()))
#       3 N.append(list_num)
# ----> 4 Avg = sum(N[1:]) / N[0]
#
# TypeError: unsupported operand type(s) for /: 'int' and 'list'

# %%
N[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-f09931b8a3fd> in <module>
# ----> 1 N[1]
#
# IndexError: list index out of range

# %%
N
# Out:
# [1, 2, 3, 4]

# %%
sum(N[1:])
# Out:
# 9
