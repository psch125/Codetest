# %%
#1330
a,b = map(int,input().split())
if a>b :
    print('>')
elif a<b :
    print('<')
else :
    print('==')
    
#9498
a = int(input())
if a>=90 :
    print('A')
elif a>=80 :
    print('B')
elif a>=70  :
    print('C')
elif a>=60 :
    print('D')
else :
    print('F')
    
#2753
a = int(input())
if a%4 ==0 and a%100 != 0 or a%400 == 0 :
    print('1')
else :
    print('0')
    
#14681
x= int(input())
y= int(input())

if x > 0 and y > 0 :	
    print('1')
elif x < 0 and y > 0 :	
    print('2')
elif x < 0 and y < 0 :	
    print('3')
else:
    print('4')

#2884
h,m = map(int, input().split())
if h>=0 and h<=23 and m>=0 and m<=59 :
    if m-45>=0 :
        print(h, m-45)
    elif m-45<0  :
        k = 45-m
        if h ==0 :
            print(23,60-k)
        else :
            print(h-1,60-k)
            
#2525
import math
A,B = map(int,input().split())
C = int(input())
h = math.floor(C/60)
m = C%60

A = A+h
B = B+m

if B >= 60 :
    A = A+1
    B = B -60
    
if A>=24:
    A = A-24 
print(A,B)

#2480
A,B,C = map(int,input().split())
list_num = [A,B,C]
list_num.sort()
if list_num[0] == list_num[1] == list_num[2] :
    money = 10000+(list_num[0]*1000)
    print(money)
if list_num[0] == list_num[1] != list_num[2] :
    money = 1000+(list_num[0]*100)
    print(money)
if list_num[0] != list_num[1] == list_num[2] :
    money = 1000+(list_num[1]*100)
    print(money)
if list_num[0] != list_num[1] != list_num[2] :
    money = 100 * list_num[2]
    print(money)
